# %%
#Loading libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datasets import load_dataset
import ast

#Loading data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()
df

#Clean data
df.job_posted_date = pd.to_datetime(df.job_posted_date)
df.job_skills=df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
import matplotlib.ticker as mticker
df_VN=df[(df['job_country']=='United States')&(df['job_title_short']=='Data Analyst')].copy()
df_VN['salary_year_avg'].sort_values(ascending=True).plot(kind='hist',bins=30,edgecolor='white')
plt.xlim(0,250000)
ax=plt.gca()
import matplotlib.ticker as mticker  # Import ticker module
ax.xaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'${int(x/1000)}K'))
